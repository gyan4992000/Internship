# %%
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import *
from selenium.webdriver.common.action_chains import ActionChains
import time
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
driver=webdriver.Chrome(r"C:\chromedriver.exe")

# %% [markdown]
# # Q1. Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
driver.get("https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos")

# %%
Rank = []
Name = []
Artist = []
Date = []
Views = []

# %%
try:
    rank = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[1]")
    name = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[2]")
    artist = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[3]")
    views = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[4]")
    date = driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']/tbody/tr/td[5]")
except:
    pass

# %%
for i in rank:
    Rank.append(i.text)

# %%
for i in name:
    Name.append(i.text)

# %%
for i in artist:
    Artist.append(i.text)

# %%
for i in date:
    Date.append(i.text)

# %%
for i in views:
    Views.append(i.text)

# %%
data = {
    'Rank' : Rank,
    'Name' : Name,
    'Artist': Artist,
    'Date' : Date,
    'Views in billions' : Views
}

# %%
MostViewsVideosOnYoutube = pd.DataFrame.from_dict(data, orient='index').transpose()[:30]

# %%
MostViewsVideosOnYoutube.to_csv("MostViewsVideosOnYoutube.csv", encoding='utf-8', header='Most Viewed Video on Youtube')

# %% [markdown]
# # Q2.  Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1
# st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
driver.get("https://www.bcci.tv/")

# %%
action = ActionChains(driver)

# %%
fixture = driver.find_element_by_xpath("/html/body/div[5]/div/div[1]/div/ul/li[1]/a")
fixture.click()

# %%
try:
    title = driver.find_elements_by_xpath("//div[@class='fixture__description u-unskewed-text']/p/strong")
    series = driver.find_elements_by_xpath("//div[@class='fixture__format-strip']/span[2]")
    place = driver.find_elements_by_xpath("//div[@class='fixture__description u-unskewed-text']/p/span")
    month =  driver.find_elements_by_xpath("//div[@class='fixture__date-details']/span[1]")
    date = driver.find_elements_by_xpath("//span[@class='fixture__date']")
    time = driver.find_elements_by_xpath("//div[@class='fixture__date-details']/span[2]")
except:
    pass

# %%
Title = []
Series = []
Place  =[]
Month = []
Date = []
Time = []

# %%
for i in title:
    Title.append(i.text)

# %%
for i in series:
    Series.append(i.text)

# %%
for i in place:
    Place.append(i.text)

# %%
for i in month:
    Month.append(i.text)

# %%
for i in date:
    Date.append(i.text)

# %%
for i in time:
    Time.append(i.text)

# %%
data  = {
    'Match Title': Title,
    'Series Name': Series,
    'Place':Place,
    'Month': Month,
    'Date':Date,
    'Time':Time
}

# %%
IndiasMatches = pd.DataFrame.from_dict(data, orient='index').transpose()

# %%
IndiasMatches.to_csv("IndiasMatches.csv", encoding='utf-8', header='''India's International Matches''')

# %% [markdown]
# # Q3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code

# %%
driver.get("https://www.guru99.com/exception-handling-selenium.html")

# %%
try:
    name = driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[1]")
    description = driver.find_elements_by_xpath("//table[@class='table table-striped']/tbody/tr/td[2]")
except:
    pass

# %%
Name = []
Description = []

# %%
for i in name:
    Name.append(i.text)
    
for i in description:
    Description.append(i.text)

# %%
data = {
    'Name': Name[1:],
    'Description': Description[1:]
}

# %%
SeleniumExceptions = pd.DataFrame.from_dict(data)

# %%
SeleniumExceptions.to_csv("Selenium Exceptions", encoding='utf-8')

# %% [markdown]
# # Q4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP(18-19)
# D) GSDP(17-18)
# E) Share(2017)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
driver=webdriver.Chrome(r"C:\chromedriver.exe")

# %%
driver.get("http://statisticstimes.com/")

# %%
btn = driver.find_element_by_xpath("//div[@class='dropdown-content']/a[3]")
btn.click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# C:\Users\GYANTR~1\AppData\Local\Temp/ipykernel_12396/49307177.py in <module>
#       1 btn = driver.find_element_by_xpath("//div[@class='dropdown-content']/a[3]")
# ----> 2 btn.click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      87     def click(self) -> None:
#      88         """Clicks the element."""
# ---> 89         self._execute(Command.CLICK_ELEMENT)
#      90
#      91     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     771             params = {}
#     772         params['id'] = self._id
# --> 773         return self._parent.execute(command, params)
#     774
#     775     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     428         response = self.command_executor.execute(driver_command, params)
#     429         if response:
# --> 430             self.error_handler.check_response(response)
#     431             response['value'] = self._unwrap_value(
#     432                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=103.0.5060.114)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00D8D953+2414931]
# 	Ordinal0 [0x00D1F5E1+1963489]
# 	Ordinal0 [0x00C0C580+836992]
# 	Ordinal0 [0x00C3A4F3+1025267]
# 	Ordinal0 [0x00C30293+983699]
# 	Ordinal0 [0x00C5449C+1131676]
# 	Ordinal0 [0x00C2FC74+982132]
# 	Ordinal0 [0x00C546B4+1132212]
# 	Ordinal0 [0x00C64812+1198098]
# 	Ordinal0 [0x00C542B6+1131190]
# 	Ordinal0 [0x00C2E860+976992]
# 	Ordinal0 [0x00C2F756+980822]
# 	GetHandleVerifier [0x00FFCC62+2510274]
# 	GetHandleVerifier [0x00FEF760+2455744]
# 	GetHandleVerifier [0x00E1EABA+551962]
# 	GetHandleVerifier [0x00E1D916+547446]
# 	Ordinal0 [0x00D25F3B+1990459]
# 	Ordinal0 [0x00D2A898+2009240]
# 	Ordinal0 [0x00D2A985+2009477]
# 	Ordinal0 [0x00D33AD1+2046673]
# 	BaseThreadInitThunk [0x7569FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x776E7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x776E7A6E+238]

# %%
india  = driver.find_element_by_xpath("/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr[143]/td[1]/a")
india.click()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# C:\Users\GYANTR~1\AppData\Local\Temp/ipykernel_12396/3242015703.py in <module>
# ----> 1 india  = driver.find_element_by_xpath("/html/body/div[3]/div[2]/div[5]/div[1]/div/table/tbody/tr[143]/td[1]/a")
#       2 india.click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     524             stacklevel=2,
#     525         )
# --> 526         return self.find_element(by=By.XPATH, value=xpath)
#     527
#     528     def find_elements_by_xpath(self, xpath) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1249             value = '[name="%s"]' % value
#    1250
# -> 1251         return self.execute(Command.FIND_ELEMENT, {
#    1252             'using': by,
#    1253             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     428         response = self.command_executor.execute(driver_command, params)
#     429         if response:
# --> 430             self.error_handler.check_response(response)
#     431             response['value'] = self._unwrap_value(
#     432                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: unknown error: unexpected command response
#   (Session info: chrome=103.0.5060.114)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00D8D953+2414931]
# 	Ordinal0 [0x00D1F5E1+1963489]
# 	Ordinal0 [0x00C0C6B8+837304]
# 	Ordinal0 [0x00BFEB34+781108]
# 	Ordinal0 [0x00BFE06A+778346]
# 	Ordinal0 [0x00BFD646+775750]
# 	Ordinal0 [0x00BFCEBC+773820]
# 	Ordinal0 [0x00BFCD59+773465]
# 	Ordinal0 [0x00C0DA70+842352]
# 	Ordinal0 [0x00C640DB+1196251]
# 	Ordinal0 [0x00C542B6+1131190]
# 	Ordinal0 [0x00C2E860+976992]
# 	Ordinal0 [0x00C2F756+980822]
# 	GetHandleVerifier [0x00FFCC62+2510274]
# 	GetHandleVerifier [0x00FEF760+2455744]
# 	GetHandleVerifier [0x00E1EABA+551962]
# 	GetHandleVerifier [0x00E1D916+547446]
# 	Ordinal0 [0x00D25F3B+1990459]
# 	Ordinal0 [0x00D2A898+2009240]
# 	Ordinal0 [0x00D2A985+2009477]
# 	Ordinal0 [0x00D33AD1+2046673]
# 	BaseThreadInitThunk [0x7569FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x776E7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x776E7A6E+238]

# %%
gdp  = driver.find_element_by_xpath("/html/body/div[3]/div[2]/div[2]/div[5]/ul/li[6]/a").click()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# C:\Users\GYANTR~1\AppData\Local\Temp/ipykernel_12396/617684258.py in <module>
# ----> 1 gdp  = driver.find_element_by_xpath("/html/body/div[3]/div[2]/div[2]/div[5]/ul/li[6]/a").click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     524             stacklevel=2,
#     525         )
# --> 526         return self.find_element(by=By.XPATH, value=xpath)
#     527
#     528     def find_elements_by_xpath(self, xpath) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1249             value = '[name="%s"]' % value
#    1250
# -> 1251         return self.execute(Command.FIND_ELEMENT, {
#    1252             'using': by,
#    1253             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     428         response = self.command_executor.execute(driver_command, params)
#     429         if response:
# --> 430             self.error_handler.check_response(response)
#     431             response['value'] = self._unwrap_value(
#     432                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: unknown error: unexpected command response
#   (Session info: chrome=103.0.5060.114)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00D8D953+2414931]
# 	Ordinal0 [0x00D1F5E1+1963489]
# 	Ordinal0 [0x00C0C6B8+837304]
# 	Ordinal0 [0x00BFEB34+781108]
# 	Ordinal0 [0x00BFE06A+778346]
# 	Ordinal0 [0x00BFD646+775750]
# 	Ordinal0 [0x00BFCEBC+773820]
# 	Ordinal0 [0x00BFCD59+773465]
# 	Ordinal0 [0x00C0DA70+842352]
# 	Ordinal0 [0x00C640DB+1196251]
# 	Ordinal0 [0x00C542B6+1131190]
# 	Ordinal0 [0x00C2E860+976992]
# 	Ordinal0 [0x00C2F756+980822]
# 	GetHandleVerifier [0x00FFCC62+2510274]
# 	GetHandleVerifier [0x00FEF760+2455744]
# 	GetHandleVerifier [0x00E1EABA+551962]
# 	GetHandleVerifier [0x00E1D916+547446]
# 	Ordinal0 [0x00D25F3B+1990459]
# 	Ordinal0 [0x00D2A898+2009240]
# 	Ordinal0 [0x00D2A985+2009477]
# 	Ordinal0 [0x00D33AD1+2046673]
# 	BaseThreadInitThunk [0x7569FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x776E7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x776E7A6E+238]

# %%
try:
    rank = driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr/td[1]")
    state = driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr/td[2]")
    n =  driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr/td[3]")
    e = driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr/td[4]")
    p = driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr/td[5]")
    gdp = driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr/td[6]")
    ni = driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr/td[7]")
    ei = driver.find_elements_by_xpath("//table[@id='table_id']/tbody/tr/td[8]")
except:
    pass

# %%
Rank = []
State = []
N = []
E = []
P = []
GDP = []
NI = []
EI = []

# %%
for i in rank:
    Rank.append(i.text)
for j in state:
    State.append(j.text)
for k in n:
    N.append(k.text)
for l in e:
    E.append(l.text)
for m in gdp:
    GDP.append(m.text)
for n in ni:
    NI.append(n.text)
for o in ei:
    EI.append(o.text)
for p in p:
    P.append(p.text)

# %%
data = {
    'Rank': Rank,
    'State Name': State,
    '19-20': N,
    '18-19':E,
    'GDP % of india': P,
    'GDP per capita': GDP,
    'GSDP 19-20':NI,
    'GSDP 18-19':EI
}

# %%
StateWiseGDPIndia = pd.DataFrame.from_dict(data)
StateWiseGDPIndia.to_csv('StateWiseGDPIndia.csv', encoding='utf-8')

# %%
driver.close()

# %% [markdown]
# # Q5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
driver=webdriver.Chrome(r"C:\chromedriver.exe")

# %%
driver.get("https://github.com/")

# %%
signin = driver.find_element_by_xpath("/html/body/div[1]/header/div/div[2]/div[2]/div[2]/a")
signin.click()

# %%
username = driver.find_element_by_xpath("//input[@id='login_field']")
user = input("Enter Your Email address: ")
username.send_keys(user)
password = driver.find_element_by_xpath("//input[@id='password']")
pwd = input("Enter your password: ")
password.send_keys(pwd)
btn = driver.find_element_by_xpath("//input[@class='btn btn-primary btn-block']")
btn.click()
# Out:
# Enter Your Email address: gyantripathi0@gmail.com
# Enter your password: Usha@1971#
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# C:\Users\GYANTR~1\AppData\Local\Temp/ipykernel_12396/2566992038.py in <module>
#       5 pwd = input("Enter your password: ")
#       6 password.send_keys(pwd)
# ----> 7 btn = driver.find_element_by_xpath("//input[@class='btn btn-primary btn-block']")
#       8 btn.click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     524             stacklevel=2,
#     525         )
# --> 526         return self.find_element(by=By.XPATH, value=xpath)
#     527
#     528     def find_elements_by_xpath(self, xpath) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1249             value = '[name="%s"]' % value
#    1250
# -> 1251         return self.execute(Command.FIND_ELEMENT, {
#    1252             'using': by,
#    1253             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     428         response = self.command_executor.execute(driver_command, params)
#     429         if response:
# --> 430             self.error_handler.check_response(response)
#     431             response['value'] = self._unwrap_value(
#     432                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//input[@class='btn btn-primary btn-block']"}
#   (Session info: chrome=103.0.5060.114)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00D8D953+2414931]
# 	Ordinal0 [0x00D1F5E1+1963489]
# 	Ordinal0 [0x00C0C6B8+837304]
# 	Ordinal0 [0x00C39500+1021184]
# 	Ordinal0 [0x00C3979B+1021851]
# 	Ordinal0 [0x00C66502+1205506]
# 	Ordinal0 [0x00C544E4+1131748]
# 	Ordinal0 [0x00C64812+1198098]
# 	Ordinal0 [0x00C542B6+1131190]
# 	Ordinal0 [0x00C2E860+976992]
# 	Ordinal0 [0x00C2F756+980822]
# 	GetHandleVerifier [0x00FFCC62+2510274]
# 	GetHandleVerifier [0x00FEF760+2455744]
# 	GetHandleVerifier [0x00E1EABA+551962]
# 	GetHandleVerifier [0x00E1D916+547446]
# 	Ordinal0 [0x00D25F3B+1990459]
# 	Ordinal0 [0x00D2A898+2009240]
# 	Ordinal0 [0x00D2A985+2009477]
# 	Ordinal0 [0x00D33AD1+2046673]
# 	BaseThreadInitThunk [0x7569FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x776E7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x776E7A6E+238]

# %%
explore  = driver.find_element_by_xpath("/html/body/div[3]/main/div/div[4]/form/div/input[12]")
explore.click()

# %%
try:
    title = driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']/a")
    desc = driver.find_elements_by_xpath("//p[@class='col-9 color-text-secondary my-1 pr-4']")
    lang = driver.find_elements_by_xpath("//span[@class='d-inline-block ml-0 mr-3']/span[2]")
    stars = driver.find_elements_by_xpath("//div[@class='f6 color-text-secondary mt-2']/a[1]")
    forks = driver.find_elements_by_xpath("//div[@class='f6 color-text-secondary mt-2']/a[2]")
except:
    pass

# %%
Title = []
Description = []
Language = []
Stars  =[]
Forks = []

# %%
for i in title:
    Title.append(i.text)
for j in desc:
    Description.append(j.text)
for k in lang:
    Language.append(k.text)
for l in stars:
    Stars.append(l.text)
for m in forks:
    Forks.append(m.text)

# %%
data = {
    'Repository Title' : Title,
    'Repository Description' : Description,
    'Language Used' : Language,
    'Stars' : Stars,
    'Forks' : Forks
}

# %%
TrendingRepository = pd.DataFrame.from_dict(data, orient='index').transpose()

# %%
TrendingRepository.to_csv("Trending Repository.csv", encoding='utf-8')

# %%
driver.close()

# %% [markdown]
# # Q6. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver=webdriver.Chrome(r"C:\chromedriver.exe")

# %%
driver.get("https://www.billboard.com/")
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# C:\Users\GYANTR~1\AppData\Local\Temp/ipykernel_12396/958630078.py in <module>
# ----> 1 driver.get("https://www.billboard.com/")
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     440         Loads a web page in the current browser session.
#     441         """
# --> 442         self.execute(Command.GET, {'url': url})
#     443
#     444     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     428         response = self.command_executor.execute(driver_command, params)
#     429         if response:
# --> 430             self.error_handler.check_response(response)
#     431             response['value'] = self._unwrap_value(
#     432                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: unknown error: cannot determine loading status
# from unknown error: unexpected command response
#   (Session info: chrome=103.0.5060.114)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00D8D953+2414931]
# 	Ordinal0 [0x00D1F5E1+1963489]
# 	Ordinal0 [0x00C0C6B8+837304]
# 	Ordinal0 [0x00BFEB34+781108]
# 	Ordinal0 [0x00BFE06A+778346]
# 	Ordinal0 [0x00BFD646+775750]
# 	Ordinal0 [0x00BFC565+771429]
# 	Ordinal0 [0x00BFCB68+772968]
# 	Ordinal0 [0x00C0785F+817247]
# 	Ordinal0 [0x00C1255B+861531]
# 	Ordinal0 [0x00C14F70+872304]
# 	Ordinal0 [0x00BFCE36+773686]
# 	Ordinal0 [0x00C12197+860567]
# 	Ordinal0 [0x00C64B55+1198933]
# 	Ordinal0 [0x00C542B6+1131190]
# 	Ordinal0 [0x00C2E860+976992]
# 	Ordinal0 [0x00C2F756+980822]
# 	GetHandleVerifier [0x00FFCC62+2510274]
# 	GetHandleVerifier [0x00FEF760+2455744]
# 	GetHandleVerifier [0x00E1EABA+551962]
# 	GetHandleVerifier [0x00E1D916+547446]
# 	Ordinal0 [0x00D25F3B+1990459]
# 	Ordinal0 [0x00D2A898+2009240]
# 	Ordinal0 [0x00D2A985+2009477]
# 	Ordinal0 [0x00D33AD1+2046673]
# 	BaseThreadInitThunk [0x7569FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x776E7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x776E7A6E+238]

# %%
hot100 = driver.find_element_by_xpath("/html/body/div[3]/header/div[2]/div/nav/ul/li[1]/a")
hot100.click()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# C:\Users\GYANTR~1\AppData\Local\Temp/ipykernel_12396/2141045538.py in <module>
#       1 hot100 = driver.find_element_by_xpath("/html/body/div[3]/header/div[2]/div/nav/ul/li[1]/a")
# ----> 2 hot100.click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      87     def click(self) -> None:
#      88         """Clicks the element."""
# ---> 89         self._execute(Command.CLICK_ELEMENT)
#      90
#      91     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     771             params = {}
#     772         params['id'] = self._id
# --> 773         return self._parent.execute(command, params)
#     774
#     775     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     428         response = self.command_executor.execute(driver_command, params)
#     429         if response:
# --> 430             self.error_handler.check_response(response)
#     431             response['value'] = self._unwrap_value(
#     432                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# WebDriverException: Message: unknown error: cannot determine loading status
# from unknown error: unexpected command response
#   (Session info: chrome=103.0.5060.114)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00D8D953+2414931]
# 	Ordinal0 [0x00D1F5E1+1963489]
# 	Ordinal0 [0x00C0C6B8+837304]
# 	Ordinal0 [0x00BFEB34+781108]
# 	Ordinal0 [0x00BFE06A+778346]
# 	Ordinal0 [0x00BFD646+775750]
# 	Ordinal0 [0x00BFC565+771429]
# 	Ordinal0 [0x00BFCB68+772968]
# 	Ordinal0 [0x00C07A85+817797]
# 	Ordinal0 [0x00C1255B+861531]
# 	Ordinal0 [0x00C14F70+872304]
# 	Ordinal0 [0x00BFCE36+773686]
# 	Ordinal0 [0x00C12197+860567]
# 	Ordinal0 [0x00C64B55+1198933]
# 	Ordinal0 [0x00C542B6+1131190]
# 	Ordinal0 [0x00C2E860+976992]
# 	Ordinal0 [0x00C2F756+980822]
# 	GetHandleVerifier [0x00FFCC62+2510274]
# 	GetHandleVerifier [0x00FEF760+2455744]
# 	GetHandleVerifier [0x00E1EABA+551962]
# 	GetHandleVerifier [0x00E1D916+547446]
# 	Ordinal0 [0x00D25F3B+1990459]
# 	Ordinal0 [0x00D2A898+2009240]
# 	Ordinal0 [0x00D2A985+2009477]
# 	Ordinal0 [0x00D33AD1+2046673]
# 	BaseThreadInitThunk [0x7569FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x776E7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x776E7A6E+238]

# %%
try:
    name = driver.find_elements_by_xpath("//span[@class='chart-element__information']/span[1]")
    artist = driver.find_elements_by_xpath("//span[@class='chart-element__information']/span[2]")
    lwr = driver.find_elements_by_xpath("//div[@class='chart-element__metas chart-element__metas--large display--flex flex--y-center']/div[2]")
    pr = driver.find_elements_by_xpath("//div[@class='chart-element__metas chart-element__metas--large display--flex flex--y-center']/div[3]")
    weeks = driver.find_elements_by_xpath("//div[@class='chart-element__metas chart-element__metas--large display--flex flex--y-center']/div[4]")
except:
    pass

# %%
Name = []
Artist = []
Last = []
Peak = []
Weeks = []

# %%
for i in name:
    Name.append(i.text)
for j in artist:
    Artist.append(i.text)
for k in lwr:
    Last.append(k.text)
for l in pr:
    Peak.append(l.text)
for m in weeks:
    Weeks.append(m.text)

# %%
data = {
    'Song Name' : Name,
    'Artist Name' : Artist,
    'Last Week Rank' : Last,
    'Peak Rank': Peak,
    'Weeks on board' : Weeks
}

# %%
Hot100 = pd.DataFrame.from_dict(data, orient='index').transpose()

# %%
Hot100.fillna("-", inplace =True)
Hot100.to_csv("Hot100 Songs.csv", encoding='utf-8')

# %% [markdown]
# # Q7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
driver=webdriver.Chrome(r"C:\chromedriver.exe")

# %%
driver.get("https://www.naukri.com/login-recruiters")

# %%
search  = driver.find_element_by_xpath("//div[@class='inpWrap']/input")
send = input("Please enter the Designation: ")
search.send_keys(send)
btn = driver.find_element_by_xpath("//button[@id='qsbFormBtn']")
btn.click()
# Out:
# Please enter the Designation: Data science

# %%
try:
    name = driver.find_elements_by_xpath("//p[@class='highlightable']/a[1]")
    designation = driver.find_elements_by_xpath("//p[@class='highlightable']/span[1]")
    company = driver.find_elements_by_xpath("//p[@class='highlightable']/a[2]")
    skills = driver.find_elements_by_xpath("//div[@class='hireSec highlightable']")
    location = driver.find_elements_by_xpath("//p[@class='highlightable']/span[2]")
except:
    pass

# %%
Name = []
Designation = []
Comapny = []
Skills = []
Location = []

# %%
for i in name:
    Name.append(i.text)
for j in designation:
    Designation.append(j.text)
for k in company:
    Comapny.append(k.text)
for l in skills:
    Skills.append(l.text)
for m in location:
    Location.append(m.text)

# %%
data = {
    'Name of Recruiter': Name,
    'Designation' : Designation,
    'Company Name' : Comapny,
    'Skills they hire for': Skills,
    'Loaction of the Company' : Location
}

# %%
DataScienceRecruiters = pd.DataFrame.from_dict(data, orient='index').transpose()

# %%
DataScienceRecruiters.to_csv("Data Science Recruiters Information.csv", encoding='utf-8')

# %%
DataScienceRecruiters
# Out:
#                                 Name of Recruiter  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5                              Vaishnavi Kudalkar
# 6    Abhishek - Only Analytics Hiring - India and
# 7   Institute for Financial Management and Resear
# 8                                  Priyanka Akiri
# 9                                 Kalpana Dumpala
# 10                                    Balu Ramesh
# 11                                        Mubarak
# 12                                 Kushal Rastogi
# 13                             Mahesh Babu Channa
# 14                                   Kapil Devang
# 15                                Sakshi Chhikara
# 16                                    Ruchi Dhote
# 17                                  Manisha Yadav
# 18                                    Riya Rajesh
# 19                           Rashmi Bhattacharjee
# 20                                  Faizan Kareem
# 21                                 Rithika dadwal
# 22                             Sandhya Khandagale
# 23                                      Shaun Rao
# 24                                  Azahar Shaikh
# 25                                  Asif Lucknowi
# 26                                          Manas
# 27                                          kumar
# 28                                   Sunil Vedula
# 29                                    Rajat Kumar
# 30                                Dhruv Dev Dubey
# 31                                      Jayanth N
# 32                                         Avodha
# 33                                       SREEDHAR
# 34                                    Priya Khare
# 35                                    Amit Sharma
# 36                                          Kanan
# 37                           Shashikant Chaudhary
# 38                                           Brad
# 39                                   Rutuja Pawar
# 40                            Madhusudhan Sridhar
# 41                                    Ankit Sinha
# 42                                 Gaurav Chouhan
# 43                                   Rashi Kacker
# 44                                        Ashwini
# 45                                   Balaji Kolli
# 46                                 Rajani Nagaraj
# 47                                    ROHIT Kumar
# 48                                 Amir Chowdhury
# 49                                     Ravi Dubey
#
#                             Designation  \
# 0                            HR Manager
# 1                     Company Recruiter
# 2                            Company HR
# 3                     Company Recruiter
# 4                           Founder CEO
# 5                          HR Executive
# 6           Recruitment Lead Consultant
# 7                     Programme Manager
# 8                            HR Manager
# 9                      Executive Hiring
# 10                     HR Administrator
# 11                           Company HR
# 12                           Company HR
# 13                         HR Team Lead
# 14                           HR Manager
# 15                 Assistant Manager HR
# 16  Senior Executive Talent Acquisition
# 17                         HR Executive
# 18           Manager Talent Acquisition
# 19                              HR Head
# 20                           HR MANAGER
# 21                         HR Recruiter
# 22                         HR Recruiter
# 23              Manager Human Resources
# 24                    Company Recruiter
# 25                             Director
# 26              Lead Talent acquisition
# 27                           Proprietor
# 28                                  CEO
# 29                          Founder CEO
# 30             Company Recruitment Head
# 31                      Project Manager
# 32       Business Development Associate
# 33               Recruitment Consultant
# 34                       Senior Manager
# 35                           Consultant
# 36         senior technology instructor
# 37             HR Recruiter/HR Excutive
# 38        Manager, Technical Recruiting
# 39                  Technical Recruiter
# 40                      Erp Implementer
# 41                       Head Analytics
# 42              Chief Technical Officer
# 43                   Sr Product Manager
# 44             Director Global Delivery
# 45                           Co Founder
# 46                           HR Manager
# 47                            Architect
# 48                     Managing Partner
# 49                  Recruitment Manager
#
#                                       Company Name  \
# 0                             Data Science Network
# 1                    Shore Infotech India Pvt. Ltd
# 2                         MARSIAN Technologies LLP
# 3            Enerlytics Software Solutions Pvt Ltd
# 4                                  LibraryXProject
# 5                              Codeachive learning
# 6       Apidel Technologies Division of Transpower
# 7                                             IFMR
# 8                    Infinitive Software Solutions
# 9                               Innominds Software
# 10                     Techvantage Systems Pvt Ltd
# 11                                        MoneyTap
# 12              QuantMagnum Technologies Pvt. Ltd.
# 13                               SocialPrachar.com
# 14                                  BISP Solutions
# 15                   BIZ INFOTECNO PRIVATE LIMITED
# 16                           Bristlecone India Ltd
# 17                                        Easi Tax
# 18                     Novelworx Digital Solutions
# 19         AXESTRACK SOFTWARE SOLUTIONS PRIVATE...
# 20                   FirstTech Consaltants Pvt.Ltd
# 21                                Affine Analytics
# 22                 Compumatrice Multimedia Pvt Ltd
# 23                              Exela Technologies
# 24                 NEAL ANALYTICS SERVICES PVT LTD
# 25                      Weupskill- Live Wire India
# 26      Autumn Leaf Consulting Services Private...
# 27                                         trainin
# 28                            Nanoprecise Sci Corp
# 29                  R.S Consultancy &amp; Services
# 30                                    Confidential
# 31        Dollarbird Information Services Pvt, Ltd
# 32                              Nikitha Palaparthi
# 33     JOBSMILL BUSINESS SOLUTIONS PRIVATE LIMITED
# 34                          Independent Consultant
# 35                                 ASCO consulting
# 36                                         NY INST
# 37  3D India Staffing Research &amp; Consulting...
# 38                                     O.C. Tanner
# 39                                   Demand Matrix
# 40                             MADHUSUDHAN SRIDHAR
# 41                                  Suntech Global
# 42                        Strategic Consulting Lab
# 43                            Impel Labs Pvt. Ltd.
# 44                                    MRP Advisers
# 45                   Saras Solutions India Pvt Ltd
# 46                                     WildJasmine
# 47                             LNT Private Limited
# 48                                     Granular.ai
# 49                     HyrEzy Talent Solutions LLP
#
#                                  Skills they hire for  \
# 0   Classic ASP Developer, Internet Marketing Prof...
# 1   .Net, Java, Data Science, Linux Administration...
# 2   Data Science, Artificial Intelligence, Machine...
# 3   Mean Stack, javascript, angularjs, mongodb, We...
# 4   Hadoop, Spark, Digital Strategy, Data Architec...
# 5                Data Science, Python, Data Analytics
# 6   Analytics, Business Intelligence, Business Ana...
# 7                                        Data Science
# 8   Oracle Dba, Data Science, Data Warehousing, ET...
# 9   Qa, Ui/ux, Java Developer, Java Architect, C++...
# 10  Machine Learning, algorithms, Go Getter, Compu...
# 11  Business Intelligence, Data Warehousing, Data ...
# 12  Office Administration, Hr Administration, tele...
# 13  Social Media, digital media maketing, seo, smm...
# 14     Big Data, Hadoop, Data Analytics, Data Science
# 15  React.js, Data Science, Java, Front End, Busin...
# 16  Qlikview, Qlik Sense, Microsoft Azure, Power B...
# 17  Telecalling, Client Interaction, Marketing, Re...
# 18                                       Data Science
# 19  Corporate Sales, Software Development, Softwar...
# 20  Data Analytics, Data Science, Machine Learning...
# 21  Data Science, Machine Learning, Python, R, Dee...
# 22  Big Data, Data Science, Artificial Intelligenc...
# 23  Java, Net, Angularjs, Hr, Infrastructure, Mana...
# 24  Data Science, Artificial Intelligence, Machine...
# 25  Technical Training, Software Development, Pres...
# 26  Software Architecture, Vp Engineering, Product...
# 27  Data Science, Hadoop, Rpas, Devops, Python, Aw...
# 28  Signal Processing, Machine Learning, Neural Ne...
# 29  Web Technologies, Project Management, Software...
# 30  Server Administartion, Verilog, Vhdl, Digital ...
# 31  Data Analytics, Managed Services, Team Leading...
# 32  Ethical Hacking, Security Operations Center, S...
# 33  Data Science, Machine Learning, Big Data Analy...
# 34  Data Science, Artificial Intelligence, analyti...
# 35  Machine Learning, Artificial Intelligence, Dat...
# 36  C, C++, Artificial Intelligence, Python, Php, ...
# 37  Relationship Management, Retail Sales, Private...
# 38                 Data Science, Software Engineering
# 39  Data Science, Big Data Analytics, Digital Mark...
# 40                  Data Science, Recruitment, Salary
# 41  B.Tech, Tableau, Statistics, R, Analytics, Tim...
# 42  Software Development, Business Intelligence, B...
# 43                   Data Science, Node.js, Angularjs
# 44  Data Science, Media Marketing, Resource Planni...
# 45  Data Analysis, Learning, Data Science, Compute...
# 46  Java, Hadoop, R, Machine Learning, Spark, Flum...
# 47  Software Development, Core Java, Unit Testing,...
# 48  Machine Learning, Data Science, Product Manage...
# 49  Walmart Interra Skeps Expressstores indifi whi...
#
#      Loaction of the Company
# 0                      Delhi
# 1   Hyderabad / Secunderabad
# 2                       Pune
# 3                  Ahmedabad
# 4              UK - (london)
# 5                     Mumbai
# 6          Vadodara / Baroda
# 7                    Chennai
# 8                  Hyderabad
# 9   Hyderabad / Secunderabad
# 10                Trivandrum
# 11     Bengaluru / Bangalore
# 12                    Mumbai
# 13  Hyderabad / Secunderabad
# 14                    Bhopal
# 15                Chandigarh
# 16                      Pune
# 17               Navi Mumbai
# 18                    Cochin
# 19                     Delhi
# 20  Hyderabad / Secunderabad
# 21                      Pune
# 22                      Pune
# 23                      Pune
# 24                      Pune
# 25                    Indore
# 26     Bengaluru / Bangalore
# 27     Bengaluru / Bangalore
# 28                     Delhi
# 29     Bengaluru / Bangalore
# 30           Mysoru / Mysore
# 31  Hyderabad / Secunderabad
# 32  Hyderabad / Secunderabad
# 33     Bengaluru / Bangalore
# 34                 New Delhi
# 35                   Chennai
# 36                   Aligarh
# 37            Salt Lake City
# 38                      Pune
# 39     Bengaluru / Bangalore
# 40                    Mumbai
# 41                    Indore
# 42     Bengaluru / Bangalore
# 43                    MYSORE
# 44  Hyderabad / Secunderabad
# 45     Bengaluru / Bangalore
# 46                    Mumbai
# 47                 Ghaziabad
# 48                      None
# 49                      None

# %% [markdown]
# # Q8. 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
driver=webdriver.Chrome(r"C:\chromedriver.exe")

# %%
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
try:
    rank = driver.find_elements_by_xpath("//div[@class='embed block']/table/tbody/tr/td[1]")
    name = driver.find_elements_by_xpath("//div[@class='embed block']/table/tbody/tr/td[2]")
    aurthor = driver.find_elements_by_xpath("//div[@class='embed block']/table/tbody/tr/td[3]")
    volume = driver.find_elements_by_xpath("//div[@class='embed block']/table/tbody/tr/td[4]")
    publisher = driver.find_elements_by_xpath("//div[@class='embed block']/table/tbody/tr/td[5]")
    genre = driver.find_elements_by_xpath("//div[@class='embed block']/table/tbody/tr/td[6]")
except:
    pass

# %%
Rank = []
Name = []
Author = []
Volume = []
Publisher = []
Genre = []

# %%
for i in rank:
    Rank.append(i.text)
for j in name:
    Name.append(j.text)
for k in aurthor:
    Author.append(k.text)
for l in volume:
    Volume.append(l.text)
for m in publisher:
    Publisher.append(m.text)
for n in genre:
    Genre.append(n.text)

# %%
data = {
    'Rank': Rank,
    'Name of the book': Name,
    'Author Name' : Author,
    'Volumes Sold' : Volume,
    'Publisher' : Publisher,
    'Genere' : Genre
}

# %%
HighestSellingNovels = pd.DataFrame.from_dict(data)

# %%
HighestSellingNovels.to_csv("Highest Selling Novels.csv", encoding='utf-8')

# %%
HighestSellingNovels
# Out:
#    Rank                                   Name of the book       Author Name  \
# 0     1                                  Da Vinci Code,The        Brown, Dan
# 1     2               Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2     3           Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3     4          Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4     5                               Fifty Shades of Grey      James, E. L.
# ..  ...                                                ...               ...
# 95   96                                          Ghost,The    Harris, Robert
# 96   97                     Happy Days with the Naked Chef     Oliver, Jamie
# 97   98              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98   99  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  100  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volumes Sold        Publisher                       Genere
# 0     5,094,805       Transworld  Crime, Thriller & Adventure
# 1     4,475,152       Bloomsbury           Children's Fiction
# 2     4,200,654       Bloomsbury           Children's Fiction
# 3     4,179,479       Bloomsbury           Children's Fiction
# 4     3,758,936     Random House              Romance & Sagas
# ..          ...              ...                          ...
# 95      807,311     Random House   General & Literary Fiction
# 96      794,201          Penguin        Food & Drink: General
# 97      792,187  Scholastic Ltd.          Young Adult Fiction
# 98      791,507            Orion           Biography: General
# 99      791,095          Penguin        Food & Drink: General
#
# [100 rows x 6 columns]

# %% [markdown]
# # Q9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
driver=webdriver.Chrome(r"C:\chromedriver.exe")

# %%
driver.get("https://www.imdb.com/list/ls095964455/")

# %%
try:
    name = driver.find_elements_by_xpath("//div[@class='lister-item-content']/h3/a")
    year = driver.find_elements_by_xpath("//div[@class='lister-item-content']/h3/span[2]")
    genre = driver.find_elements_by_xpath("//div[@class='lister-item-content']/p/span[5]")
    run  = driver.find_elements_by_xpath("//div[@class='lister-item-content']/p/span[3]")
    ratings  = driver.find_elements_by_xpath("//div[@class='ipl-rating-widget']/div/span[2]")
    votes = driver.find_elements_by_xpath("//p[@class='text-muted text-small'][3]/span[2]")
except:
    pass

# %%
Name = []
Year = []
Genre = []
Runtime = []
Ratings = []
Votes = []

# %%
for i in name:
    Name.append(i.text)
for j in year:
    Year.append(j.text)
for k in genre:
    Genre.append(k.text)
for l in run:
    Runtime.append(l.text)
for m in ratings:
    Ratings.append(m.text)
for n in votes:
    Votes.append(n.text)

# %%
data = {
    'Name': Name,
    'Year Span': Year,
    'Genre' : Genre,
    'Runtime': Runtime,
    'Ratings' : Ratings,
    'Votes':Votes
}

# %%
MostWatchedTvSeries = pd.DataFrame.from_dict(data)

# %%
MostWatchedTvSeries.to_csv("Most Watched TV Series.csv", encoding='utf-8')

# %%
MostWatchedTvSeries
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#     Runtime Ratings      Votes
# 0    57 min     9.2  2,009,995
# 1    51 min     8.7  1,092,203
# 2    44 min     8.2    955,369
# 3    60 min     7.5    285,620
# 4    43 min     7.6    245,264
# ..      ...     ...        ...
# 95   42 min     7.4     49,107
# 96   50 min     7.8     59,897
# 97   42 min     8.1    192,302
# 98   45 min     7.1     40,610
# 99  572 min     8.6    231,364
#
# [100 rows x 6 columns]

# %% [markdown]
# # Q10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
driver=webdriver.Chrome(r"C:\chromedriver.exe")

# %%
driver.get("https://archive.ics.uci.edu/ml/index.php")

# %%
click  = driver.find_element_by_xpath("//table[2]/tbody/tr/td/span/b")
click.click()

# %%
try:
    name = driver.find_elements_by_xpath("//table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]")
    datatype = driver.find_elements_by_xpath("//table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]")
    task = driver.find_elements_by_xpath("//table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]")
    attrobutetype = driver.find_elements_by_xpath("//table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]")
    instances = driver.find_elements_by_xpath("//table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]")
    noattribute = driver.find_elements_by_xpath("//table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]")
    year = driver.find_elements_by_xpath("//table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]")
except:
    pass

# %%
Name = []
Datatype = []
Task = []
Attribute = []
Instances =  []
NoAttribute = []
Year = []

# %%
for i in name:
    Name.append(i.text)
for j in datatype:
    Datatype.append(j.text)
for k in task:
    Task.append(k.text)
for l in attrobutetype:
    Attribute.append(l.text)
for m in instances:
    Instances.append(m.text)
for n in noattribute:
    NoAttribute.append(n.text)
for o in year:
    Year.append(o.text)

# %%
data = {
    'Dataset Name': Name,
    'Data Type': Datatype,
    'Task' : Task,
    'Attribute Type': Attribute,
    'No of Instances' : Instances,
    'No of Attribute': NoAttribute,
    'Year': Year
}

# %%
Datasets = pd.DataFrame.from_dict(data)

# %%
Datasets[1:].to_csv("Datasets.csv", encoding='utf-8')

# %%
Datasets
# Out:
#                                           Dataset Name  \
# 0                                                 Name
# 1                                              Abalone
# 2                                                Adult
# 3                                            Annealing
# 4                         Anonymous Microsoft Web Data
# ..                                                 ...
# 618    Influenza outbreak event prediction via Twit...
# 619                      Turkish Music Emotion Dataset
# 620                      Maternal Health Risk Data Set
# 621                          Room Occupancy Estimation
# 622    Image Recognition Task Execution Times in Mo...
#
#                       Data Type                  Task  \
# 0                    Data Types          Default Task
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                 Multivariate        Classification
# 4                                Recommender-Systems
# ..                          ...                   ...
# 618               Multivariate        Classification
# 619               Multivariate        Classification
# 620                                   Classification
# 621  Multivariate, Time-Series        Classification
# 622                 Univariate            Regression
#
#                   Attribute Type No of Instances No of Attribute   Year
# 0                Attribute Types     # Instances    # Attributes   Year
# 1    Categorical, Integer, Real            4177               8   1995
# 2          Categorical, Integer           48842              14   1996
# 3    Categorical, Integer, Real             798              38
# 4                   Categorical           37711             294   1998
# ..                           ...             ...             ...    ...
# 618               Integer, Real           75840             525   2020
# 619               Integer, Real             400              50   2020
# 620                                        1014               7   2020
# 621                        Real           10129              16   2021
# 622                        Real            4000               2   2021
#
# [623 rows x 7 columns]
